# %%
x<-10

# %%
x
# Out:
# [1] 10

# %%
class(x)
# Out:
# [1] "numeric"

# %%
is.integer(x)
# Out:
# [1] FALSE

# %%
x<-as.integer(10)

# %%
x
# Out:
# [1] 10

# %%
class(x)
# Out:
# [1] "integer"

# %%
is.integer(x)
# Out:
# [1] TRUE

# %%
x<-10L

# %%
x
# Out:
# [1] 10

# %%
class(x)
# Out:
# [1] "integer"

# %%
is.integer(x)
# Out:
# [1] TRUE

# %%
x<-as.integer(10.25)

# %%
x
# Out:
# [1] 10

# %%
class(x)
# Out:
# [1] "integer"

# %%
is.integer(x)
# Out:
# [1] TRUE

# %%
x<-as.integer(5.75)

# %%
x
# Out:
# [1] 5

# %%
class(x)
# Out:
# [1] "integer"

# %%
is.integer(x)
# Out:
# [1] TRUE

# %%
x<-as.integer('John')
# Out:
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”

# %%
x
# Out:
# [1] NA

# %%
class(x)
# Out:
# [1] "integer"

# %%
is.integer(x)
# Out:
# [1] TRUE

# %%
x<-3+4i

# %%
x
# Out:
# [1] 3+4i

# %%
class(x)
# Out:
# [1] "complex"

# %%
x<-4i

# %%
x
# Out:
# [1] 0+4i

# %%
class(x)
# Out:
# [1] "complex"

# %%
x<-TRUE

# %%
x
# Out:
# [1] TRUE

# %%
class(x)
# Out:
# [1] "logical"

# %%
x<-T

# %%
x
# Out:
# [1] TRUE

# %%
class(x)
# Out:
# [1] "logical"

# %%
x<-F

# %%
x
# Out:
# [1] FALSE

# %%
class(x)
# Out:
# [1] "logical"

# %%
x<-'Jack'

# %%
x
# Out:
# [1] "Jack"

# %%
class(x)
# Out:
# [1] "character"

# %%
x<-'3.75'

# %%
x
# Out:
# [1] "3.75"

# %%
class(x)
# Out:
# [1] "character"

# %%
x<-as.character(3.75)

# %%
x
# Out:
# [1] "3.75"

# %%
class(x)
# Out:
# [1] "character"

# %%
is.character(x)
# Out:
# [1] TRUE
